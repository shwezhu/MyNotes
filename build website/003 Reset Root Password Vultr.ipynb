# %% [markdown]
# 就是重启服务器的时候得快速返回到连接的终端, 等待开机最前的几秒按`esc`退出键进入设置页面, 就像重装系统, 然后教程里说修改选项的第一行, 其实并不一定在第一行, 我的就是编辑的最后的一个选项, 你要看哪一行里有`linux16`开头的字符, 如下图

# %% [markdown]
# ![Screenshot%202023-04-07%20at%2017.46.45.png](attachment:Screenshot%202023-04-07%20at%2017.46.45.png)

# %% [markdown]
# ![Screenshot%202023-04-07%20at%2017.40.14.png](attachment:Screenshot%202023-04-07%20at%2017.40.14.png)

# %% [markdown]
# 然后哩就要按照教程说的找到以`linux16`开头的字符串, 然后按照教程里的修改就行了, 如下图

# %% [markdown]
# ![Screenshot%202023-04-07%20at%2017.26.54.png](attachment:Screenshot%202023-04-07%20at%2017.26.54.png)

# %% [markdown]
# - [How to Reset the Root Password on a Vultr Cloud Server - Vultr.com](https://www.vultr.com/docs/boot-into-single-user-mode-reset-root-password)

# %% [markdown]
# 按照教程修改完密码之后, 再在远程登录的时候输入root(root是默认的用户名而已, 你以后可以创建其他的用户)和你新的password就可以啦,

# %% [markdown]
# ![Screenshot%202023-04-07%20at%2017.44.43.png](attachment:Screenshot%202023-04-07%20at%2017.44.43.png)
