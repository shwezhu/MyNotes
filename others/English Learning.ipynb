# %% [markdown]
# # English Learning
# ---

# %% [markdown]
# ## Day1
# ---
#
# ### windy
# + adjective
#
# > Although the day was `windy`, all the guideposts she needed to orient herself were readable.
#
#
# ### overweight
# + adjective
#
# > Now Frolic was middle-aged, `overweight`, lazy, and no longer needing to chew.
# Lower-income women are more likely than other women to be `overweight`, though the pattern among men may be the opposite.
# Being `overweight` or obese are both terms for having more `body fat` than what is considered healthy. However, the term "obese" generally means a much higher amount of `body fat` than "overweight."
#
# ### fat
# + noun
# Fat is a form of body tissue on animals. It’s a squishy layer that stores energy and protects organs.
# + adjective
# Fat is also an adjective meaning chubby or thick, as in a fat piglet or a fat wallet full of money.
#
# ### chubby
# + adjective
# Someone who's chubby is plump or `slightly overweight`. If the vet mentions that your cat's getting a little chubby, you might need to cut down on the cat treats.
#
# > Jhon’s chubby face lit up with a rueful grin.
#
# ### stick
# + noun
# a small thin branch of a tree
#
# ### respond
# + verb
# > She hasn't yet responded to my letter.
# My mother responded to my request with a firm no.
# I asked him his name, but he didn't respond.
# She never responded to my letter.
# He responded politely to her questions.
#
#
# ### response
# + noun
# > What was their response to the question?
# You get a point for each correct response.
# 95% of customers can expect a response to their enquiries within 10 days.
#
#
# ### react
# + verb
# > The police must be able to `react swiftly` in an emergency.
# The committee `reacted positively` to the proposals.
#
# + **react to something**
# > The army has `reacted to the situation` by increasing investment in recruitment.
#
# ### equal
# + adjective
# > Cut it into four `equal` parts.
#
# **equal in something** The two countries `are roughly equal in` size.
#
# **equal to somebody/something** One pound `is roughly equal to` one dollar.
#
# ### console
# + verb
#
# >  `console somebody/yourself` Nothing could console him when his wife died.
#  I didn't like lying but I consoled myself that it was for a good cause.
#  ‘Never mind,’ Anne consoled her.

# %% [markdown]
# ##  Spoken English
#
# + **Hang in there!**
# remain persistent and determined in difficult circumstances.
# > "in the second half, we just had to hang in there"
#
# + **keep going!**
# make an effort to live normally when in a difficult situation.
# > she had to `keep going` for the sake of her boys
#
# + **go for it!**
# If you go for it, you make a big effort to achieve something or you decide to do something. When you set the right goals for yourself, you will feel ready and willing to go for it.
# > Don't throw away your chances — just go for it!

# %% [markdown]
# + **Come back/Go back**
#
# "Come back" is used from someone who is in a place and is talking about someone else coming to that place.
# Ex. "My mother will come back home tomorrow" = it means that I'm at home, while my mother is in another place.
# "Go back" is used from another place to another place.
#
# > Ex. "I will go back home tomorrow." = it means that I'm in another place and I will go home tomorrow.
#
# >I will be there in 5 minutes. Sorry!
# I’ll be home soon..
#
# "I'm at home" is what you say when someone asks you on your cell phone or IM (Instant Messenger) where you are located: "Where are you?" "I'm at home right now."

# %% [markdown]
# + **Are you…?** is used in the following situations:
#
# To ask someone about his identity. For example, Are you a vegetarian/Jewish/an artist?
#
# To ask someone what he’s doing at the present moment. For example, Are you writing/dreaming/typing?
#
# To ask someone about his identity (adjective). For example, Are you mad/serious/sick?
#
# + **Do you…?** is used in the following situations:
#
# To ask someone what he generally does. For example, Do you smoke/drink/dance?
#
# To ask about the ownership/possession. For example, Do you have a cat?/Do you own that house?
#
# I think it’s best to give you a few examples:
#
# > Do you like swimming? Are you a swimmer?
# Do you play tennis? Are you a tennis player?
# Do you climb mountains? Are you a mountain climber?
# Do you feel okay? Are you okay?

# %% [markdown]
# + **not really**
#
# —used to say "no" in a way that is not very forceful or definite
#
# > "Was the movie good?" "Not really."
# "Do you want to go to a movie?" "No, not really."

# %% [markdown]
# ### understand/noted
#
# An example:
# Someone may say "can you fold your clothes like this instead in the future?" And you can respond "noted" to let them know that you will try to remember to do that in he future. For understood/understand, someone can teach you how to do a math problem and once you figure out how they are doing it, you now understand the problem.
#
# We also use understand when responding to people being unable to do something. For example, if someone says "I'm sorry I can't help you today, I'm sick" we would respond with "I understand" to let them know that it is okay and we don't mind.
#
# **respond politely**
#
# Often the best way to indicate that you have understood is to summarize in one sentence what your understanding will lead you to do next.
# e.g.,
#
# > "I understand. I will get back to you with the revisions you requested by Monday."
#
# > "I see. I will make sure to include or discuss your idea that .... in my next paper."
#
# or
#
# > I really appreciated your explanations in the last session I attended, they helped me to grasp/understand [topic] and now I feel much more confident. Thank you.
#
# > Thank you so much for your clear and unambiguous explanations on [topic]. They have helped me tremendously.

# %% [markdown]
# ## Day 2
# ---
#
# ### Words
#
# #### knives and forks
#
# ####  experienced
# + adjective: having knowledge or skill in a particular job or activity.
#
# > She's highly experienced in software development.
# He's very experienced in looking after animals.
# The staff are all highly experienced.
#
# #### skilled
# + adjective: having enough ability, experience and knowledge to be able to do something well.
#
# > a skilled engineer/negotiator/craftsman
# She wasn't very skilled with the camera yet.

# %% [markdown]
# ## Day 3
# ---
#
# ### Words
#
# #### scarf
# + noun: A scarf is a wide piece of fabric that's worn around the neck or over the head. That long, warm, wooly thing you wrap around your throat in the winter is a scarf.
#
# #### wear
#
# + verb
#
# > He was wearing a new suit.
# All delegates must wear a badge.
# He had forgotten to wear his gloves.
# Do you have to wear a suit for work?
#
# #### takeout
# Takeout means hot cooked food which you buy from a shop or restaurant and eat somewhere else.
#
# > Lots of people want to turn to `takeout` when we re feeling too sick to cook， which is very convenient.
#
# #### takeaway
# + noun
# > Why not call the `takeaway` tonight instead of eating outside？
#
# #### dining
# + noun:the act of eating dinner
#
# > Mum was at the `dining room` table surrounded by bank papers when I got back from school.
#
# #### delivery man/delivery guy

# %% [markdown]
# ### Sentence
# + **Don't mention it**
# a polite expression used to indicate that an apology or an expression of thanks is not necessary.
#
# + **four section**
#
# primiary school, middle scool, and high school...
#
# + **order takeout**
#
# > A：Hello，can I order takeout，please？
#
# > B：I am so sorry. The delivery guy is so busy for today is raining heavily. Is it ok for you to wait for an hour ?

# %% [markdown]
# ## Day 4
# ---
#
# ### Words
#
# #### take (a) bath
#
# #### take (a) shower
# > Take a quick shower before you get dressed
#
# #### take a nap
# If you’re really tired during the day, go ahead and `take a nap`, even if you have to hide under your desk. A nap is a brief sleep. Good night.
# > Maybe what you really need is a good nap
#
# #### take a seat
#
# #### take a sip
# When you drink a small amount of something, you sip it. If your cocoa is extremely hot, you should probably sip it until it cools off a little bit.
#
# #### helmet
# a protective headgear made of hard material to resist blows.
#
# #### Sleeping on your stomach/lying on my stomach
#
# ##### Mid-Autumn Festival
#
# > Mid-Autumn Festival will `fall on` September 21st (Thuesday)
#
# In China, it's a reunion time for families, just like Thanksgiving.
#
# #### Moon Festival/Mooncake Festival
#
# It traditionally falls on the 15th day of the eighth month in the `Chinese lunar calendar`, which is in September or early October in the `Gregorian calendar`.

# %% [markdown]
# ### Sentence
#
# + **how about you**
# —used to ask someone to tell one something in response to what one has just said
# > I like skiing and hiking. How about you? What do you like?
# I'm ready to go. How about you?
#
# > Q: “How did you do on the test” A: “I think I passed. How about you?”
#
# > After finishing a five-mile hike with a bunch of friends “I’m starving! How about you?”
